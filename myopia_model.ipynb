# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
df = pd.read_csv("myopia.csv")
target = df["MYOPIC"]
df = df.drop(["MYOPIC"], axis =1)
df
# Out:
#      AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0      6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1      6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2      6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3      6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4      5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# ..   ...    ...        ...    ...    ...    ...      ...     ...     ...
# 613    6  0.678  22.400000  3.663  3.803  14.93        2       0       7
# 614    6  0.665  22.500000  3.570  3.378  15.56        6       0       1
# 615    6  1.834  22.940001  3.624  3.424  15.89        8       0       0
# 616    6  0.665  21.920000  3.688  3.598  14.64       12       2       1
# 617    6  0.802  22.260000  3.530  3.484  15.25       25       0       2
#
#      STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY
# 0          0    10         34      1      1
# ...

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(df)
new_df = pd.DataFrame(scaled, columns = df.columns[0:])
new_df
# Out:
#           AGE     SPHEQ        AL       ACD        LT       VCD   SPORTHR  \
# 0   -0.420219 -1.363917 -0.892861  0.483784 -0.281443 -1.019792  4.150661
# 1   -0.420219 -0.308612 -0.171840  0.535910 -0.967997 -0.130763 -0.998898
# 2   -0.420219  0.604386 -0.009977 -0.506628 -0.177812  0.215809  0.257092
# 3   -0.420219 -0.441325 -0.436703  1.230936  0.456927 -0.974587  0.759488
# 4   -1.823978 -0.166306  1.167204  0.422970 -0.566427  1.180178  0.257092
# ..        ...       ...       ...       ...       ...       ...       ...
# 613 -0.420219 -0.196686 -0.142410  0.366499  1.694021 -0.673220 -1.250096
# 614 -0.420219 -0.217472  0.004738 -0.037486 -1.058674  0.276082 -0.747700
# 615 -0.420219  1.651696  0.652187  0.197086 -0.760735  0.773335 -0.496502
# 616 -0.420219 -0.217472 -0.848716  0.475096  0.366251 -1.110201  0.005894
# 617 -0.420219  0.001583 -0.348415 -0.211242 -0.372120 -0.191036  1.638681
#
#        READHR    COMPHR   STUDYHR      TVHR  DIOPTERHR     MOMMY     DADMY
# ...

# %%
pca = PCA(n_components = .9)
myopia_pca = pca.fit_transform(new_df)
myopia_pca_df = pd.DataFrame(myopia_pca, columns = ["principal component 1", "principal component 2",\
                                                    "principal component 3","principal component 4",\
                                                    "principal component 5", "principal component 6",\
                                                    "principal component 7","principal component 8",\
                                                   "principal component 9","principal component 10", ])
myopia_pca_df
# Out:
#      principal component 1  principal component 2  principal component 3  \
# 0                 0.535503               1.145004              -1.385019
# 1                -0.624706              -1.575786              -0.794253
# 2                -0.933479              -0.717076               0.820150
# 3                 0.106354               1.192475              -0.024441
# 4                -0.388503              -2.839655              -0.229767
# ..                     ...                    ...                    ...
# 613              -0.237547               1.146547              -1.546054
# 614              -0.649011              -1.796952              -0.823592
# 615              -0.890082              -2.308005               0.268102
# 616              -1.124000               0.451890               0.001659
# 617              -0.691534              -0.737046              -1.052900
#
#      principal component 4  principal component 5  principal component 6  \
# ...

# %%
# low learning rates tend to lead to less clusters in data [points are more likely to converge]
# high learning rates cause more clusters to form by making it harder for points to converge
# perplexity is how to balance attention between local and global aspects of data
    
tsne = TSNE(learning_rate= 50, perplexity = 50 )
tsne_features = tsne.fit_transform(myopia_pca_df)
tsne_features.shape
# Out:
# /Users/brain/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# (618, 2)

# %%
plt.scatter(tsne_features[:,0], tsne_features[:,1])
plt.show()

# %%
# show data colored by target
plt.scatter(tsne_features[:,0], tsne_features[:,1], c=target)
plt.show()

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(tsne_features)
    inertia.append(km.inertia_)
    km.score

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.head(7)
# Out:
#    k        inertia
# 0  1  101346.921875
# 1  2   55537.468750
# 2  3   31999.910156
# 3  4   23826.730469
# 4  5   18014.988281
# 5  6   15267.927734
# 6  7   12769.167969

# %%
# Plot the elbow curve to find the best candidate(s) for k
plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow curve for myopia')
plt.show()

# %% [markdown]
# Analysis :
# The patients could be clustered into about 3-5 clusters with 5 being the most ideal, any more would result in too specific of groups and would not be necessary, and any less would leave out some distinctions.
